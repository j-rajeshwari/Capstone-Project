# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
car_features=pd.read_excel('Car features.xlsx')
insurance_claim=pd.read_excel('Insurance claim.xlsx')
policy_features=pd.read_excel('Policy features.xlsx')

# %%
print(car_features.shape)
print(insurance_claim.shape)
print(policy_features.shape)
# Out:
# (58515, 38)
# (58515, 2)
# (58515, 6)

# %%
car_features.columns
# Out:
# Index(['policy_id', 'make', 'segment', 'model', 'fuel_type', 'max_torque',
#        'max_power', 'engine_type', 'airbags', 'is_esc',
#        'is_adjustable_steering', 'is_tpms', 'is_parking_sensors',
#        'is_parking_camera', 'rear_brakes_type', 'displacement', 'cylinder',
#        'transmission_type', 'gear_box', 'steering_type', 'turning_radius',
#        'length', 'width', 'height', 'gross_weight', 'is_front_fog_lights',
#        'is_rear_window_wiper', 'is_rear_window_washer',
#        'is_rear_window_defogger', 'is_brake_assist', 'is_power_door_locks',
#        'is_central_locking', 'is_power_steering',
#        'is_driver_seat_height_adjustable', 'is_day_night_rear_view_mirror',
#        'is_ecw', 'is_speed_alert', 'ncap_rating'],
#       dtype='object')

# %%
insurance_claim.columns
# Out:
# Index(['policy_id', 'is_claim'], dtype='object')

# %%
policy_features.columns
# Out:
# Index(['policy_id', 'policy_tenure', 'age_of_car', 'age_of_policyholder',
#        'area_cluster', 'population_density'],
#       dtype='object')

# %%
car_features.head(2)
# Out:
#   policy_id  make segment model fuel_type    max_torque         max_power  \
# 0   ID00001     1       A    M1       CNG  60Nm@3500rpm  40.36bhp@6000rpm
# 1   ID00002     1       A    M1       CNG  60Nm@3500rpm  40.36bhp@6000rpm
#
#          engine_type  airbags is_esc  ... is_rear_window_defogger  \
# 0  F8D Petrol Engine      2.0     No  ...                      No
# 1  F8D Petrol Engine      2.0     No  ...                      No
#
#   is_brake_assist is_power_door_locks is_central_locking is_power_steering  \
# 0              No                  No                 No               Yes
# 1              No                  No                 No               Yes
#
#    is_driver_seat_height_adjustable  is_day_night_rear_view_mirror is_ecw  \
# 0                                No                             No     No
# 1                                No                             No     No
#
#    is_speed_alert ncap_rating
# 0             Yes           0
# ...

# %%
insurance_claim.head(2)
# Out:
#   policy_id  is_claim
# 0   ID00001         0
# 1   ID00002         0

# %%
policy_features.head(2)
# Out:
#   policy_id  policy_tenure  age_of_car  age_of_policyholder area_cluster  \
# 0   ID00001       0.515874        0.05             0.644231           C1
# 1   ID00002       0.672619        0.02             0.375000           C2
#
#    population_density
# 0              4990.0
# 1             27003.0

# %% [markdown]
#  <h1>Does the dataset have duplicates?</h1>

# %%
insurance_claim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58515 entries, 0 to 58514
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   policy_id  58515 non-null  object
#  1   is_claim   58515 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 914.4+ KB

# %%
insurance_claim.describe()
# Out:
#            is_claim
# count  58515.000000
# mean       0.063967
# std        0.244695
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %% [markdown]
# <h3>#No null values in insurance_claim</h3>

# %%
policy_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58515 entries, 0 to 58514
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   policy_id            58515 non-null  object
#  1   policy_tenure        58495 non-null  float64
#  2   age_of_car           58510 non-null  float64
#  3   age_of_policyholder  58508 non-null  float64
#  4   area_cluster         58509 non-null  object
#  5   population_density   58503 non-null  float64
# dtypes: float64(4), object(2)
# memory usage: 2.7+ MB

# %%
policy_features.describe()
# Out:
#        policy_tenure    age_of_car  age_of_policyholder  population_density
# count   58495.000000  58510.000000         58508.000000        58503.000000
# mean        0.611175      0.069413             0.469423        18828.559817
# std         0.414092      0.056726             0.122901        17661.056419
# min         0.002735      0.000000             0.288462          290.000000
# 25%         0.210247      0.020000             0.365385         6112.000000
# 50%         0.573766      0.060000             0.451923         8794.000000
# 75%         1.038968      0.110000             0.548077        27003.000000
# max         1.396641      1.000000             1.000000        73430.000000

# %% [markdown]
# <h3>#Null values in policy_features : policy_tenure, age_of_car, age_of_policy_holder, area_cluster, population_density</h3>

# %%
car_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58515 entries, 0 to 58514
# Data columns (total 38 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   policy_id                         58515 non-null  object
#  1   make                              58515 non-null  int64
#  2   segment                           58515 non-null  object
#  3   model                             58515 non-null  object
#  4   fuel_type                         58489 non-null  object
#  5   max_torque                        58508 non-null  object
#  6   max_power                         58512 non-null  object
#  7   engine_type                       58512 non-null  object
#  8   airbags                           58506 non-null  float64
#  9   is_esc                            58512 non-null  object
#  10  is_adjustable_steering            58508 non-null  object
# ...

# %%
car_features.describe()
# Out:
#                make       airbags  displacement      cylinder      gear_box  \
# count  58515.000000  58506.000000  58508.000000  58508.000000  58515.000000
# mean       1.763479      3.136362   1162.289106      3.626923      5.245305
# std        1.137011      1.832328    266.302251      0.483627      0.430271
# min        1.000000      1.000000    796.000000      3.000000      5.000000
# 25%        1.000000      2.000000    796.000000      3.000000      5.000000
# 50%        1.000000      2.000000   1197.000000      4.000000      5.000000
# 75%        3.000000      6.000000   1493.000000      4.000000      5.000000
# max        5.000000      6.000000   1498.000000      4.000000      6.000000
#
#        turning_radius        length         width        height  gross_weight  \
# count    58515.000000  58515.000000  58515.000000  58515.000000  58515.000000
# mean         4.852805   3850.377510   1672.212287   1553.322960   1385.226198
# ...

# %% [markdown]
# <h3>#Null values in car_features : fuel_type, max_torque, max_power, engine_type, airbags, is_esc, is_adjustable_steering, is_tpms, is_parking_sensors, is_parking_camera, displacement, cylinder</h3>

# %%
insurance_claim.duplicated().any()
# Out:
# np.False_

# %%
car_features.duplicated().any()
# Out:
# np.False_

# %%
policy_features.duplicated().any()
# Out:
# np.False_

# %% [markdown]
# <h1>Is the dataset balanced?</h1>

# %%
counts=insurance_claim['is_claim'].value_counts()
print(counts)
# Out:
# is_claim
# 0    54772
# 1     3743
# Name: count, dtype: int64

# %%
print(insurance_claim['is_claim'].value_counts(normalize=True))
# Out:
# is_claim
# 0    0.936033
# 1    0.063967
# Name: proportion, dtype: float64

# %%
sns.countplot(x='is_claim',data=insurance_claim)
# Out:
# <Axes: xlabel='is_claim', ylabel='count'>

# %%
majority=counts.max()
minority=counts.min()
imbalance_ratio=majority/minority
print("Imbalance ratio: ",imbalance_ratio)
# Out:
# Imbalance ratio:  14.633181939620625

# %% [markdown]
# <h1>No, dataset is not balanced</h1>

# %%
car_features_merged=pd.merge(car_features,insurance_claim,on='policy_id',how='outer')
policy_features_merged=pd.merge(policy_features,insurance_claim,on='policy_id',how='outer')

# %% [markdown]
# <h1>Relation between policy features and claims</h1>

# %%
policy_features_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58515 entries, 0 to 58514
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   policy_id            58515 non-null  object
#  1   policy_tenure        58495 non-null  float64
#  2   age_of_car           58510 non-null  float64
#  3   age_of_policyholder  58508 non-null  float64
#  4   area_cluster         58509 non-null  object
#  5   population_density   58503 non-null  float64
#  6   is_claim             58515 non-null  int64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 3.1+ MB

# %%
policy_features_merged.isnull().sum()
# Out:
# policy_id               0
# policy_tenure          20
# age_of_car              5
# age_of_policyholder     7
# area_cluster            6
# population_density     12
# is_claim                0
# dtype: int64

# %% [markdown]
# <h3>#Null values in policy_features : policy_tenure, age_of_car, age_of_policy_holder, area_cluster, population_density</h3>

# %%
policy_features_merged.head(1)
# Out:
#   policy_id  policy_tenure  age_of_car  age_of_policyholder area_cluster  \
# 0   ID00001       0.515874        0.05             0.644231           C1
#
#    population_density  is_claim
# 0              4990.0         0

# %%
print(policy_features_merged['is_claim'].value_counts())
# Out:
# is_claim
# 0    54772
# 1     3743
# Name: count, dtype: int64

# %%
print(policy_features_merged['is_claim'].value_counts(normalize=True))
# Out:
# is_claim
# 0    0.936033
# 1    0.063967
# Name: proportion, dtype: float64

# %%
policy_features_merged['is_claim'].mean()
# Out:
# np.float64(0.06396650431513287)

# %%
numerical_features_pf=policy_features_merged.select_dtypes(exclude=['object']).columns.tolist()
print('Numerical features of Policy features are: ',numerical_features_pf)
# Out:
# Numerical features of Policy features are:  ['policy_tenure', 'age_of_car', 'age_of_policyholder', 'population_density', 'is_claim']

# %%
categorical_features_pf=policy_features_merged.select_dtypes(include=['object']).columns.tolist()
print('Categorical features of Policy features are: ',categorical_features_pf)
# Out:
# Categorical features of Policy features are:  ['policy_id', 'area_cluster']

# %%
policy_features_merged.describe()
# Out:
#        policy_tenure    age_of_car  age_of_policyholder  population_density  \
# count   58495.000000  58510.000000         58508.000000        58503.000000
# mean        0.611175      0.069413             0.469423        18828.559817
# std         0.414092      0.056726             0.122901        17661.056419
# min         0.002735      0.000000             0.288462          290.000000
# 25%         0.210247      0.020000             0.365385         6112.000000
# 50%         0.573766      0.060000             0.451923         8794.000000
# 75%         1.038968      0.110000             0.548077        27003.000000
# max         1.396641      1.000000             1.000000        73430.000000
#
#            is_claim
# count  58515.000000
# mean       0.063967
# std        0.244695
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
#Not useful
policy_features_merged.describe(include=['O']).T
# Out:
#               count unique      top   freq
# policy_id     58515  58515  ID58515      1
# area_cluster  58509     22       C8  13630

# %%
for col in policy_features_merged:
    print(f'{col} : {policy_features_merged[col].nunique()}')
# Out:
# policy_id : 58515
# policy_tenure : 58495
# age_of_car : 49
# age_of_policyholder : 75
# area_cluster : 22
# population_density : 22
# is_claim : 2

# %%
policy_features_merged['area_cluster'].unique()
# Out:
# array(['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9', 'C10', nan,
#        'C11', 'C12', 'C13', 'C14', 'C15', 'C16', 'C17', 'C18', 'C19',
#        'C20', 'C21', 'C22'], dtype=object)

# %%
policy_features_merged['population_density'].unique()
# Out:
# array([ 4990., 27003.,  4076., 21622., 34738., 13051.,  6112.,  8794.,
#        17804., 73430.,  6108., 34791.,  5410.,  7788.,   290., 16206.,
#        65567.,    nan, 35036., 27742., 20905.,  3264., 16733.])

# %%
policy_features_merged.hist(column=['policy_tenure','age_of_car','age_of_policyholder','population_density'],bins=10,rwidth=0.9,grid=False)
# Out:
# array([[<Axes: title={'center': 'policy_tenure'}>,
#         <Axes: title={'center': 'age_of_car'}>],
#        [<Axes: title={'center': 'age_of_policyholder'}>,
#         <Axes: title={'center': 'population_density'}>]], dtype=object)

# %%
plt.figure(figsize=(4,3))
corr_pf=policy_features_merged[numerical_features_pf].corr()
sns.heatmap(corr_pf,annot=True,cmap='GnBu')
# Out:
# <Axes: >

# %%
rows_with_null_pf=policy_features_merged[policy_features_merged.isnull().any(axis=1)]

# %%
rows_with_null_pf
# Out:
#     policy_id  policy_tenure  age_of_car  age_of_policyholder area_cluster  \
# 14    ID00015            NaN         NaN                  NaN          NaN
# 15    ID00016            NaN         NaN                  NaN          NaN
# 16    ID00017            NaN         NaN                  NaN          NaN
# 17    ID00018            NaN         NaN                  NaN          NaN
# 49    ID00050       0.345261         NaN                  NaN           C5
# 125   ID00126       0.064652        0.00                  NaN          NaN
# 126   ID00127       0.096462        0.17                  NaN          NaN
# 242   ID00243       0.515313        0.00             0.423077           C9
# 243   ID00244       1.046147        0.11             0.480769          C17
# 244   ID00245       0.966715        0.01             0.538462          C10
# 245   ID00246       0.365102        0.03             0.355769          C13
# ...

# %%
rows_with_null_pf.shape
# Out:
# (33, 7)

# %% [markdown]
# <h1>Relation between car features and claims</h1>

# %%
car_features_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58515 entries, 0 to 58514
# Data columns (total 39 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   policy_id                         58515 non-null  object
#  1   make                              58515 non-null  int64
#  2   segment                           58515 non-null  object
#  3   model                             58515 non-null  object
#  4   fuel_type                         58489 non-null  object
#  5   max_torque                        58508 non-null  object
#  6   max_power                         58512 non-null  object
#  7   engine_type                       58512 non-null  object
#  8   airbags                           58506 non-null  float64
#  9   is_esc                            58512 non-null  object
#  10  is_adjustable_steering            58508 non-null  object
# ...

# %%
car_features_merged.head(1)
# Out:
#   policy_id  make segment model fuel_type    max_torque         max_power  \
# 0   ID00001     1       A    M1       CNG  60Nm@3500rpm  40.36bhp@6000rpm
#
#          engine_type  airbags is_esc  ... is_brake_assist is_power_door_locks  \
# 0  F8D Petrol Engine      2.0     No  ...              No                  No
#
#   is_central_locking is_power_steering is_driver_seat_height_adjustable  \
# 0                 No               Yes                               No
#
#    is_day_night_rear_view_mirror  is_ecw is_speed_alert  ncap_rating is_claim
# 0                             No      No            Yes            0        0
#
# [1 rows x 39 columns]

# %%
car_features_merged.describe()
# Out:
#                make       airbags  displacement      cylinder      gear_box  \
# count  58515.000000  58506.000000  58508.000000  58508.000000  58515.000000
# mean       1.763479      3.136362   1162.289106      3.626923      5.245305
# std        1.137011      1.832328    266.302251      0.483627      0.430271
# min        1.000000      1.000000    796.000000      3.000000      5.000000
# 25%        1.000000      2.000000    796.000000      3.000000      5.000000
# 50%        1.000000      2.000000   1197.000000      4.000000      5.000000
# 75%        3.000000      6.000000   1493.000000      4.000000      5.000000
# max        5.000000      6.000000   1498.000000      4.000000      6.000000
#
#        turning_radius        length         width        height  gross_weight  \
# count    58515.000000  58515.000000  58515.000000  58515.000000  58515.000000
# mean         4.852805   3850.377510   1672.212287   1553.322960   1385.226198
# ...

# %%
car_features_merged.isnull().sum()
# Out:
# policy_id                            0
# make                                 0
# segment                              0
# model                                0
# fuel_type                           26
# max_torque                           7
# max_power                            3
# engine_type                          3
# airbags                              9
# is_esc                               3
# is_adjustable_steering               7
# is_tpms                              3
# is_parking_sensors                   7
# is_parking_camera                    3
# rear_brakes_type                     0
# displacement                         7
# cylinder                             7
# transmission_type                    0
# gear_box                             0
# steering_type                        0
# turning_radius                       0
# length                               0
# width                                0
# height                               0
# ...

# %% [markdown]
# <h3>#Null values in car_features : fuel_type, max_torque, max_power, engine_type, airbags, is_esc, is_adjustable_steering, is_tpms, is_parking_sensors, is_parking_camera, displacement, cylinder</h3>

# %%
categorical_features_cf=car_features_merged.select_dtypes(include=['object']).columns.tolist()
print('Categorical features of Policy features are: ',categorical_features_cf)
# Out:
# Categorical features of Policy features are:  ['policy_id', 'segment', 'model', 'fuel_type', 'max_torque', 'max_power', 'engine_type', 'is_esc', 'is_adjustable_steering', 'is_tpms', 'is_parking_sensors', 'is_parking_camera', 'rear_brakes_type', 'transmission_type', 'steering_type', 'is_front_fog_lights', 'is_rear_window_wiper', 'is_rear_window_washer', 'is_rear_window_defogger', 'is_brake_assist', 'is_power_door_locks', 'is_central_locking', 'is_power_steering', 'is_driver_seat_height_adjustable', 'is_day_night_rear_view_mirror', 'is_ecw', 'is_speed_alert']

# %%
#Not useful
policy_features_merged.describe(include=['O']).T
# Out:
#               count unique      top   freq
# policy_id     58515  58515  ID58515      1
# area_cluster  58509     22       C8  13630

# %%
car_features_merged.hist(column=['make', 'airbags', 'displacement', 'cylinder', 'gear_box', 'turning_radius', 'length', 'width',
                                 'height', 'gross_weight', 'ncap_rating'],figsize=(10,15),bins=10,rwidth=0.9,grid=False)
# Out:
# array([[<Axes: title={'center': 'make'}>,
#         <Axes: title={'center': 'airbags'}>,
#         <Axes: title={'center': 'displacement'}>],
#        [<Axes: title={'center': 'cylinder'}>,
#         <Axes: title={'center': 'gear_box'}>,
#         <Axes: title={'center': 'turning_radius'}>],
#        [<Axes: title={'center': 'length'}>,
#         <Axes: title={'center': 'width'}>,
#         <Axes: title={'center': 'height'}>],
#        [<Axes: title={'center': 'gross_weight'}>,
#         <Axes: title={'center': 'ncap_rating'}>, <Axes: >]], dtype=object)

# %%
car_features_merged['max_torque_value']=car_features_merged['max_torque'].str.split('Nm@').str[0].astype(float)
car_features_merged['max_torque_rpm']=car_features_merged['max_torque'].str.split('Nm@').str[1].str.replace("rpm","").astype(float)

# %%
car_features_merged['max_power_value']=car_features_merged['max_power'].str.split('bhp@').str[0].astype(float)
car_features_merged['max_power_rpm']=car_features_merged['max_power'].str.split('bhp@').str[1].str.replace("rpm","").astype(float)

# %%
car_features_merged.head(1)
# Out:
#   policy_id  make segment model fuel_type    max_torque         max_power  \
# 0   ID00001     1       A    M1       CNG  60Nm@3500rpm  40.36bhp@6000rpm
#
#          engine_type  airbags is_esc  ... is_driver_seat_height_adjustable  \
# 0  F8D Petrol Engine      2.0     No  ...                               No
#
#   is_day_night_rear_view_mirror is_ecw is_speed_alert ncap_rating  is_claim  \
# 0                            No     No            Yes           0         0
#
#    max_torque_value max_torque_rpm  max_power_value max_power_rpm
# 0              60.0         3500.0            40.36        6000.0
#
# [1 rows x 43 columns]

# %%
car_features_merged['is_esc']=car_features_merged['is_esc'].str.lower().map({"yes":1,"no":0})
car_features_merged['is_adjustable_steering']=car_features_merged['is_adjustable_steering'].str.lower().map({"yes":1,"no":0})

car_features_merged['is_tpms']=car_features_merged['is_tpms'].str.lower().map({"yes":1,"no":0})
car_features_merged['is_parking_sensors']=car_features_merged['is_parking_sensors'].str.lower().map({"yes":1,"no":0})

car_features_merged['is_parking_camera']=car_features_merged['is_parking_camera'].str.lower().map({"yes":1,"no":0})
car_features_merged['is_rear_window_wiper']=car_features_merged['is_rear_window_wiper'].str.lower().map({"yes":1,"no":0})

car_features_merged['is_rear_window_washer']=car_features_merged['is_rear_window_washer'].str.lower().map({"yes":1,"no":0})
car_features_merged['is_rear_window_defogger']=car_features_merged['is_rear_window_defogger'].str.lower().map({"yes":1,"no":0})

car_features_merged['is_brake_assist']=car_features_merged['is_brake_assist'].str.lower().map({"yes":1,"no":0})
car_features_merged['is_power_door_locks']=car_features_merged['is_power_door_locks'].str.lower().map({"yes":1,"no":0})

car_features_merged['is_central_locking']=car_features_merged['is_central_locking'].str.lower().map({"yes":1,"no":0})
car_features_merged['is_power_steering']=car_features_merged['is_power_steering'].str.lower().map({"yes":1,"no":0})

car_features_merged['is_driver_seat_height_adjustable']=car_features_merged['is_driver_seat_height_adjustable'].str.lower().map({"yes":1,"no":0})
car_features_merged['is_day_night_rear_view_mirror']=car_features_merged['is_day_night_rear_view_mirror'].str.lower().map({"yes":1,"no":0})

car_features_merged['is_ecw']=car_features_merged['is_ecw'].str.lower().map({"yes":1,"no":0})
car_features_merged['is_speed_alert']=car_features_merged['is_speed_alert'].str.lower().map({"yes":1,"no":0})

# %%
for col in car_features_merged:
    print(f'{col} : {car_features_merged[col].nunique()}')
# Out:
# policy_id : 58515
# make : 5
# segment : 6
# model : 11
# fuel_type : 3
# max_torque : 9
# max_power : 9
# engine_type : 11
# airbags : 3
# is_esc : 2
# is_adjustable_steering : 2
# is_tpms : 2
# is_parking_sensors : 2
# is_parking_camera : 2
# rear_brakes_type : 2
# displacement : 9
# cylinder : 2
# transmission_type : 2
# gear_box : 2
# steering_type : 3
# turning_radius : 9
# length : 9
# width : 10
# height : 11
# gross_weight : 10
# is_front_fog_lights : 2
# is_rear_window_wiper : 2
# is_rear_window_washer : 2
# is_rear_window_defogger : 2
# is_brake_assist : 2
# is_power_door_locks : 2
# is_central_locking : 2
# is_power_steering : 2
# is_driver_seat_height_adjustable : 2
# is_day_night_rear_view_mirror : 2
# is_ecw : 2
# is_speed_alert : 2
# ncap_rating : 5
# is_claim : 2

# %%
#rear_brakes_type,transmission_type,gear_box,steering_type ----- binary encoding or one-hot encoding may be applied

# %%
rows_with_null_cf=car_features_merged[car_features_merged.isnull().any(axis=1)]

# %%
rows_with_null_cf
# Out:
#       policy_id  make  segment model fuel_type      max_torque  \
# 58438   ID58439     1       B2    M7       NaN   113Nm@4400rpm
# 58439   ID58440     1        A    M1       NaN    60Nm@3500rpm
# 58440   ID58441     1       B2    M6       NaN   113Nm@4400rpm
# 58441   ID58442     3       C2    M4       NaN   250Nm@2750rpm
# 58442   ID58443     3       C2    M4       NaN   250Nm@2750rpm
# 58443   ID58444     1        A    M1       NaN    60Nm@3500rpm
# 58444   ID58445     1        A    M1       NaN    60Nm@3500rpm
# 58445   ID58446     1       B2    M6       NaN   113Nm@4400rpm
# 58446   ID58447     3       C2    M4       NaN   250Nm@2750rpm
# 58447   ID58448     1       C1    M2       NaN   113Nm@4400rpm
# 58448   ID58449     1        A    M1       NaN    60Nm@3500rpm
# 58449   ID58450     1       B2    M6       NaN   113Nm@4400rpm
# 58450   ID58451     1       B2    M7       NaN   113Nm@4400rpm
# 58451   ID58452     3       C2    M4       NaN   250Nm@2750rpm
# ...

# %%
rows_with_null_cf.shape
# Out:
# (40, 39)

# %%
car_features_merged.head(10)
# Out:
#   policy_id  make segment model fuel_type     max_torque          max_power  \
# 0   ID00001     1       A    M1       CNG   60Nm@3500rpm   40.36bhp@6000rpm
# 1   ID00002     1       A    M1       CNG   60Nm@3500rpm   40.36bhp@6000rpm
# 2   ID00003     1       A    M1       CNG   60Nm@3500rpm   40.36bhp@6000rpm
# 3   ID00004     1      C1    M2    Petrol  113Nm@4400rpm   88.50bhp@6000rpm
# 4   ID00005     2       A    M3    Petrol   91Nm@4250rpm   67.06bhp@5500rpm
# 5   ID00006     3      C2    M4    Diesel  250Nm@2750rpm  113.45bhp@4000rpm
# 6   ID00007     4      B2    M5    Diesel  200Nm@3000rpm   88.77bhp@4000rpm
# 7   ID00008     1      B2    M6    Petrol  113Nm@4400rpm   88.50bhp@6000rpm
# 8   ID00009     3      C2    M4    Diesel  250Nm@2750rpm  113.45bhp@4000rpm
# 9   ID00010     1      B2    M7    Petrol  113Nm@4400rpm   88.50bhp@6000rpm
#
#                  engine_type  airbags  is_esc  ...  \
# 0          F8D Petrol Engine      2.0     0.0  ...
# ...

# %%
car_features_merged.columns
# Out:
# Index(['policy_id', 'make', 'segment', 'model', 'fuel_type', 'max_torque',
#        'max_power', 'engine_type', 'airbags', 'is_esc',
#        'is_adjustable_steering', 'is_tpms', 'is_parking_sensors',
#        'is_parking_camera', 'rear_brakes_type', 'displacement', 'cylinder',
#        'transmission_type', 'gear_box', 'steering_type', 'turning_radius',
#        'length', 'width', 'height', 'gross_weight', 'is_front_fog_lights',
#        'is_rear_window_wiper', 'is_rear_window_washer',
#        'is_rear_window_defogger', 'is_brake_assist', 'is_power_door_locks',
#        'is_central_locking', 'is_power_steering',
#        'is_driver_seat_height_adjustable', 'is_day_night_rear_view_mirror',
#        'is_ecw', 'is_speed_alert', 'ncap_rating', 'is_claim',
#        'max_torque_value', 'max_torque_rpm', 'max_power_value',
#        'max_power_rpm'],
#       dtype='object')

# %%
numerical_features_cf=car_features_merged.select_dtypes(exclude=['object']).columns.tolist()
print('Numerical features of car features are: ',numerical_features_cf)
# Out:
# Numerical features of car features are:  ['make', 'airbags', 'is_esc', 'is_adjustable_steering', 'is_tpms', 'is_parking_sensors', 'is_parking_camera', 'displacement', 'cylinder', 'gear_box', 'turning_radius', 'length', 'width', 'height', 'gross_weight', 'is_rear_window_wiper', 'is_rear_window_washer', 'is_rear_window_defogger', 'is_brake_assist', 'is_power_door_locks', 'is_central_locking', 'is_power_steering', 'is_driver_seat_height_adjustable', 'is_day_night_rear_view_mirror', 'is_ecw', 'is_speed_alert', 'ncap_rating', 'is_claim', 'max_torque_value', 'max_torque_rpm', 'max_power_value', 'max_power_rpm']

# %%
plt.figure(figsize=(21,21))
corr_cf=car_features_merged[numerical_features_cf].corr()
sns.heatmap(corr_cf,annot=True,cmap='GnBu')
# Out:
# <Axes: >
